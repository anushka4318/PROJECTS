# %% [markdown]
# <a href="https://colab.research.google.com/github/anushka4318/PROJECTS/blob/main/SIMPLE_LINEAR_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv('/content/Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# PREPROCESSING

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# SPLIT THE X Y

# %%
from sklearn.model_selection import train_test_split
X=dataset['YearsExperience'].values
Y=dataset['Salary'].values

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %% [markdown]
# MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train.reshape(-1,1),Y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred=model.predict(np.array(X_test).reshape(-1,1))
# Out:
# array([[ 40748.96184072],
#        [122699.62295594],
#        [ 64961.65717022],
#        [ 63099.14214487],
#        [115249.56285456],
#        [107799.50275317]])
